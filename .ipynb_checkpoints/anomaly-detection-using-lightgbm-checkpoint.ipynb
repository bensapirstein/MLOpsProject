# %%
import os
# %load_ext autoreload
# %autoreload 2

# %%
import sys

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import random
import math

from IPython.display import display, Markdown
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# Out:
# input/skoltech-anomaly-benchmark-skab/SKAB/.DS_Store
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/6.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/7.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/5.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/4.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/0.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/1.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/3.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/2.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/15.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/14.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/10.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/11.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/13.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/12.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/9.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve1/8.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/23.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/22.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/20.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/21.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/19.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/18.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/16.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/17.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/15.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/14.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/11.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/13.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/12.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/other/9.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/anomaly-free/anomaly-free.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve2/0.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve2/1.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve2/3.csv
# input/skoltech-anomaly-benchmark-skab/SKAB/valve2/2.csv

# %%
import os
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # 1. Abstract
#
# We use the TS(Time Series) data of circulation pump offered by Skolkovo Institute of Science and Technology. These data are 8-dimensional TS data obtained from sensors.
#
# First of all, we visualize the data by TS plotting  and calculating the correlation coefficient.
# Next, we implement data splitting, smoothing and standardization.
#
# When we make the anomaly detecting model using LightGBM, we start by data processing which is appropriate for LightGBM.
#
# After this, we train the model using the training data and search the hyper parameter like learning_rate, max_depth randomly using the validation data.
# Finally, we assess the generalization performance using the test data.

# %% [markdown]
# # 2. About dataset
#
# We use the TS data of circulation pump offered by Skolkovo Institute of Science and Technology. These data are 8-dimensional TS data obtained from sensors.
# So, we have 8 dimensional characteristics.
#
# 【Characteristics】
#
# ①Accelerometer1RMS
#
# ②Accelerometer2RMS
#
# ③Current
#
# ④Pressure
#
# ⑤Temperature
#
# ⑥Thermocouple
#
# ⑦Voltage
#
# ⑧Volume Flow RateRMS
#
# We explain each characteristics using below figure. At first, the dynamics of water circulation is as follows: water in a tank is circulating by a water pump.
#
# Accelerometer1RMS and Accelerometer2RMS are the data obtained from vibration sensor.
#
# Current and Voltage are motor's value.
#
# Pressure,Thermocouple,Volume Flow RateRMS are the data related to circulated water.
#
# Temperature is the engine body's value.
#
# ![1_データセットについて_図1.png](attachment:a7e05286-4748-494e-9133-ce4be10b576b.png)

# %% [markdown]
# In this TS data, we are given the supervised data(normal:0 anomaly:1) for each time point and we use the valve1_data. The valve_1 data includes the anomaly waveform occurring when valve is closed.
#
# The purpose of this data analysis is that we let the model understand the relation between the TS waveform and the anomaly as the supervised learning.
# Finally, we want the model to predict the anomaly for unknown data.
#
# As the supervised learning method, we introduce the window which is parameterized by "look_back" and calculate the stat. like mean, min and max within the window area.
# We adopt them the explanatory variable.
#
# Also, we set the anomaly label at the right end of window as the objective variable and construct the predict model by LightGBM.
#
# For the furthermore detail information, you can check below URL:
# https://www.kaggle.com/datasets/yuriykatser/skoltech-anomaly-benchmark-skab

# %% [markdown]
# # 3. Visualize the data
#
# **loading of valve1_data**
#
# Valve1_data consists of the number of data : 18162 , normal class number of data : 11853 and anomaly class number of data : 6309.

# %%
#module import
#loading the dataset
all_files=[]
for dirname,_,filenames in os.walk('input'):
    for filename in filenames:
        if filename.endswith('csv'):
            all_files.append(f'{dirname}/{filename}')
all_files.sort()

valve1_dat={file.split('/')[-1]:pd.read_csv(file,sep=';',index_col='datetime',parse_dates=True)
              for file in all_files if 'valve1' in file}

#concatenate data(order in time series by sort_index)
valve1_data=pd.concat(list(valve1_dat.values()),axis=0).sort_index()
display(valve1_data)
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-03-09 10:14:33           0.026588           0.040111  1.330200  0.054711
# 2020-03-09 10:14:34           0.026170           0.040452  1.353990  0.382638
# 2020-03-09 10:14:35           0.026199           0.039419  1.540060  0.710565
# 2020-03-09 10:14:36           0.026027           0.039641  1.334580  0.382638
# 2020-03-09 10:14:37           0.026290           0.040273  1.078510 -0.273216
# ...                                ...                ...       ...       ...
# 2020-03-09 15:34:37           0.027605           0.039760  0.622996  0.382638
# 2020-03-09 15:34:38           0.027286           0.039613  0.600692  0.054711
# 2020-03-09 15:34:39           0.027202           0.041440  0.450323  0.054711
# 2020-03-09 15:34:40           0.027180           0.041831  0.855527  0.382638
# 2020-03-09 15:34:41           0.027832           0.041008  0.822494 -0.273216
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS  \
# datetime
# 2020-03-09 10:14:33      79.3366       26.0199  233.062              32.0000
# 2020-03-09 10:14:34      79.5158       26.0258  236.040              32.0000
# 2020-03-09 10:14:35      79.3756       26.0265  251.380              32.0000
# 2020-03-09 10:14:36      79.6097       26.0393  234.392              32.0000
# 2020-03-09 10:14:37      79.6109       26.0420  225.342              32.0000
# ...                          ...           ...      ...                  ...
# 2020-03-09 15:34:37      68.4247       24.4370  230.358              32.9673
# 2020-03-09 15:34:38      68.0598       24.4356  231.373              32.0000
# 2020-03-09 15:34:39      68.1836       24.4379  210.605              32.0337
# 2020-03-09 15:34:40      68.2250       24.4310  229.566              32.9673
# 2020-03-09 15:34:41      68.2268       24.4383  235.451              32.0337
#
#                      anomaly  changepoint
# datetime
# 2020-03-09 10:14:33      0.0          0.0
# 2020-03-09 10:14:34      0.0          0.0
# 2020-03-09 10:14:35      0.0          0.0
# 2020-03-09 10:14:36      0.0          0.0
# 2020-03-09 10:14:37      0.0          0.0
# ...                      ...          ...
# 2020-03-09 15:34:37      0.0          0.0
# 2020-03-09 15:34:38      0.0          0.0
# 2020-03-09 15:34:39      0.0          0.0
# 2020-03-09 15:34:40      0.0          0.0
# 2020-03-09 15:34:41      0.0          0.0
#
# [18162 rows x 10 columns]

# %% [markdown]
# Changepoint is not necessary because we consider the outlier detection problem.

# %% [markdown]
# **TS plotting**
#
# We plot TS data(valve1_data) for each characteristics.

# %%
#TS data plotting(Change point is not use)

for column in valve1_data.columns[:-1]:
    plt.figure(figsize=(13,8))
    plt.plot(valve1_data[column].values)
    ax=plt.gca()
    
    plt.legend()
    plt.title(column)
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# There are no missing values in valve1_data.

# %%
valve1_data.isnull().sum(axis=0)
# Out:
# Accelerometer1RMS      0
# Accelerometer2RMS      0
# Current                0
# Pressure               0
# Temperature            0
# Thermocouple           0
# Voltage                0
# Volume Flow RateRMS    0
# anomaly                0
# changepoint            0
# dtype: int64

# %% [markdown]
# **Correlation coefficient**
#
# We examine the relation between the characteristics and the objective variable by using python seaborn.
#
# For concretely, we make the heatmap of the correlation coefficient.
#
# As a result, we found that having the strong negative correlation -0.62 between "Volume Flow RateRMS" and "anomaly".

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

#Correlation coefficient
plt.figure(figsize=(8,8))
data=valve1_data.drop(columns='changepoint')
sns.heatmap(data.corr(),annot=True,fmt='.2g')
# Out:
# <Axes: >

# %% [markdown]
# # 4. Data Pre-processing
#
# We implement data pre-processing before the supervised learning.

# %% [markdown]
# **Divide into train,valid and test groups**
#
# The context of TS data is important to predict the anomaly, so we don't use train_test_split() function.
#
# If you use this function, the data is mixed randomly and it leads to destroy the context. We divide the data like train:valid:test=7:2:1.

# %%
#train_pre(valve1_data is dataframe)
train_pre=valve1_data

#train_pre ⇒ train:valid_pre=7:3
train_pre_size=len(train_pre)
train_size=int(train_pre_size*0.7)
train=train_pre[0:train_size]
x_train_pre=train.drop('anomaly',axis=1)
x_train=x_train_pre.drop('changepoint',axis=1)
y_train=train['anomaly'].values

#valid_pre ⇒ valid:test=2:1
valid_pre_size=train_pre_size-train_size
valid_size=int(valid_pre_size*0.66)
valid=train_pre[train_size:train_size+valid_size]
x_valid_pre=valid.drop('anomaly',axis=1)
x_valid=x_valid_pre.drop('changepoint',axis=1)
y_valid=valid['anomaly'].values

test=train_pre[train_size+valid_size:]
x_test_pre=test.drop('anomaly',axis=1)
x_test=x_test_pre.drop('changepoint',axis=1)
y_test=test['anomaly'].values

# %%
display(x_train)
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-03-09 10:14:33           0.026588           0.040111  1.330200  0.054711
# 2020-03-09 10:14:34           0.026170           0.040452  1.353990  0.382638
# 2020-03-09 10:14:35           0.026199           0.039419  1.540060  0.710565
# 2020-03-09 10:14:36           0.026027           0.039641  1.334580  0.382638
# 2020-03-09 10:14:37           0.026290           0.040273  1.078510 -0.273216
# ...                                ...                ...       ...       ...
# 2020-03-09 13:59:08           0.028173           0.040152  1.153800  0.054711
# 2020-03-09 13:59:09           0.028142           0.039445  0.981651  0.382638
# 2020-03-09 13:59:10           0.028283           0.040615  0.966102  0.054711
# 2020-03-09 13:59:11           0.028778           0.041955  0.827491 -0.601143
# 2020-03-09 13:59:12           0.028282           0.041094  1.204300  0.054711
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS
# datetime
# 2020-03-09 10:14:33      79.3366       26.0199  233.062              32.0000
# 2020-03-09 10:14:34      79.5158       26.0258  236.040              32.0000
# 2020-03-09 10:14:35      79.3756       26.0265  251.380              32.0000
# 2020-03-09 10:14:36      79.6097       26.0393  234.392              32.0000
# 2020-03-09 10:14:37      79.6109       26.0420  225.342              32.0000
# ...                          ...           ...      ...                  ...
# 2020-03-09 13:59:08      66.9568       24.7372  218.170              32.9781
# 2020-03-09 13:59:09      66.9901       24.7381  232.774              32.0000
# 2020-03-09 13:59:10      66.8982       24.7404  227.030              32.0226
# 2020-03-09 13:59:11      66.8706       24.7499  228.784              32.9781
# 2020-03-09 13:59:12      66.9742       24.7464  235.070              32.0000
#
# [12713 rows x 8 columns]

# %%
display(x_valid)
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-03-09 13:59:13           0.028482           0.040634  1.524940 -0.273216
# 2020-03-09 13:59:14           0.027507           0.040703  1.303390  0.054711
# 2020-03-09 13:59:15           0.027513           0.040440  1.134970  0.054711
# 2020-03-09 13:59:16           0.027721           0.039620  1.319540  0.054711
# 2020-03-09 13:59:17           0.028237           0.040403  1.353650  0.054711
# ...                                ...                ...       ...       ...
# 2020-03-09 15:02:15           0.026906           0.040246  1.131370  0.382638
# 2020-03-09 15:02:16           0.026948           0.038869  1.397970  0.054711
# 2020-03-09 15:02:17           0.026791           0.038432  0.717252  0.054711
# 2020-03-09 15:02:19           0.027878           0.038045  0.809988  0.054711
# 2020-03-09 15:02:20           0.027328           0.037528  1.035860  0.054711
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS
# datetime
# 2020-03-09 13:59:13      66.9312       24.7440  244.074              32.0226
# 2020-03-09 13:59:14      66.9704       24.7351  230.644              32.9781
# 2020-03-09 13:59:15      67.0253       24.7351  216.261              32.0000
# 2020-03-09 13:59:16      66.9084       24.7379  231.529              32.0226
# 2020-03-09 13:59:17      66.8116       24.7443  253.006              32.9781
# ...                          ...           ...      ...                  ...
# 2020-03-09 15:02:15      68.3998       24.5080  234.733              32.0000
# 2020-03-09 15:02:16      68.4817       24.5268  212.247              32.0000
# 2020-03-09 15:02:17      68.4652       24.5268  239.494              32.0000
# 2020-03-09 15:02:19      68.3824       24.5182  232.930              32.0000
# 2020-03-09 15:02:20      68.5077       24.5075  210.885              32.0300
#
# [3596 rows x 8 columns]

# %%
display(x_test)
# Out:
#                      Accelerometer1RMS  Accelerometer2RMS   Current  Pressure  \
# datetime
# 2020-03-09 15:02:21           0.027773           0.039028  1.326890  0.054711
# 2020-03-09 15:02:22           0.027711           0.039946  1.110150  0.054711
# 2020-03-09 15:02:23           0.027657           0.040355  1.273900  0.710565
# 2020-03-09 15:02:24           0.027274           0.039846  0.819551  0.054711
# 2020-03-09 15:02:25           0.027238           0.039922  1.101930  0.054711
# ...                                ...                ...       ...       ...
# 2020-03-09 15:34:37           0.027605           0.039760  0.622996  0.382638
# 2020-03-09 15:34:38           0.027286           0.039613  0.600692  0.054711
# 2020-03-09 15:34:39           0.027202           0.041440  0.450323  0.054711
# 2020-03-09 15:34:40           0.027180           0.041831  0.855527  0.382638
# 2020-03-09 15:34:41           0.027832           0.041008  0.822494 -0.273216
#
#                      Temperature  Thermocouple  Voltage  Volume Flow RateRMS
# datetime
# 2020-03-09 15:02:21      68.5600       24.5135  231.830              32.9709
# 2020-03-09 15:02:22      68.5861       24.5136  239.315              32.0000
# 2020-03-09 15:02:23      68.4256       24.5084  240.306              32.0300
# 2020-03-09 15:02:24      68.6263       24.5139  236.042              32.9709
# 2020-03-09 15:02:25      68.4726       24.5196  236.624              32.0000
# ...                          ...           ...      ...                  ...
# 2020-03-09 15:34:37      68.4247       24.4370  230.358              32.9673
# 2020-03-09 15:34:38      68.0598       24.4356  231.373              32.0000
# 2020-03-09 15:34:39      68.1836       24.4379  210.605              32.0337
# 2020-03-09 15:34:40      68.2250       24.4310  229.566              32.9673
# 2020-03-09 15:34:41      68.2268       24.4383  235.451              32.0337
#
# [1853 rows x 8 columns]

# %% [markdown]
# We split the data into the normal class and the anomaly class for each data group(train group, valid group and test group).
#
# When we plot histgrams for each characteristic, we found that all data group are distributed at almost same location.
#
# It means that the train group are covered over the test group. So if we train the model precisely, the model which has the generalization performance can be obtained.
#
# Also, the normal distribution and the anomaly distribution for each characteristic are not apart each other ,so it is not appropriate to construct model by using just one characteristic.
#
# Thus we use all characteristic and expect that using all characteristic leads to separativeness of 2 class :normal and anomaly.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings('ignore')

#*** split into free and anomaly ***
def free_anomaly_split(X,Y):
    free=[]
    anomaly=[]
    
    for x,y in zip(X,Y):
        if y==0:
            free.append(x)
        elif y==1:
            anomaly.append(x)
    
    free=np.array(free)
    anomaly=np.array(anomaly)
        
    return free,anomaly

x_train_free,x_train_anomaly=free_anomaly_split(x_train.values,y_train)
x_valid_free,x_valid_anomaly=free_anomaly_split(x_valid.values,y_valid)
x_test_free,x_test_anomaly=free_anomaly_split(x_test.values,y_test)

#histgram of normal and anomaly
features={1:'Accelerometer1RMS',2:'Accelerometer2RMS',3:'Current',4:'Pressure',5:'Temperature',6:'Thermocouple',7:'Voltage',8:'Volume Flow RateRMS'}
bins=None

for key,col in features.items():
    plt.figure(figsize=(16,6))
    sns.distplot(x_train_free[:,key-1],bins=bins,label='train_free')
    sns.distplot(x_train_anomaly[:,key-1],bins=bins,label='train_anomaly')
    sns.distplot(x_valid_free[:,key-1],bins=bins,label='valid_free')
    sns.distplot(x_valid_anomaly[:,key-1],bins=bins,label='valid_anomaly')
    sns.distplot(x_test_free[:,key-1],bins=bins,label='test_free')
    sns.distplot(x_test_anomaly[:,key-1],bins=bins,label='test_anomaly')   
    
    plt.title(col)
    plt.legend()
    plt.show()

# %% [markdown]
# **Data smoothing using Kaiser window**
#
# TS data includes the residual error. If this error has large number, it is difficult to capture the meaning pattern from original TS data.
#
# In this case, data smoothing is useful to cancel the residual. We choose Kaiser as the window function.

# %%
def smooth_curve(x):
    #x=1 dimension array
    window_len = 11
    s = np.r_[x[window_len-1:0:-1], x, x[-1:-window_len:-1]]
    w = np.kaiser(window_len, 2)
    y = np.convolve(w/w.sum(), s, mode='valid')
    return y[5:len(y)-5]

x_train_win=np.zeros_like(x_train.values)
x_valid_win=np.zeros_like(x_valid.values)
x_test_win=np.zeros_like(x_test.values)

data_dim=8
for i in range(0,data_dim):
    x_train_win[:,i]=smooth_curve(x_train.values[:,i].flatten())
    x_valid_win[:,i]=smooth_curve(x_valid.values[:,i].flatten())
    x_test_win[:,i]=smooth_curve(x_test.values[:,i].flatten())

# %% [markdown]
# We compare the TS data before and after data smoothing.
#
# We can check that the residual error is cancel out almost.
# (Blue:TS data before data smoothing. Red:TS data after data smoothing)

# %%
x1=np.arange(0,12713)
x2=np.arange(12713,16309)
x3=np.arange(16309,18162)

x_all_data=pd.concat([x_train,x_valid,x_test],ignore_index=False)

#features=['Accelerometer1RMS','Accelerometer2RMS','Current','Pressure','Temperature','Thermocouple','Voltage','Volume Flow RateRMS']
columns = features.values()
mat=np.concatenate([x_train_win,x_valid_win,x_test_win],axis=0)

x_all_data_win=pd.DataFrame(mat,columns=columns)

# filter the anomalies and plot the results

for key, column in features.items():
    plt.figure(figsize=(13,8))
    plt.plot(x_all_data[column].values,color='b')
    plt.plot(x_all_data_win[column].values,color='g')

    # plot the anomalies as red vertical lines

    
    
    ax=plt.gca()
    y_min,y_max=ax.get_ylim()
    
    y1=[y_min]*len(x1)
    y2=[y_max]*len(x1)
    plt.fill_between(x1,y1,y2,facecolor='g',alpha=0.3,label='train')
    
    y1=[y_min]*len(x2)
    y2=[y_max]*len(x2)
    plt.fill_between(x2,y1,y2,facecolor='b',alpha=0.3,label='valid')
    
    y1=[y_min]*len(x3)
    y2=[y_max]*len(x3)
    plt.fill_between(x3,y1,y2,facecolor='r',alpha=0.3,label='test')
    
    plt.legend()
    plt.title(column)
    plt.show()

# %% [markdown]
# **Data Standardization**
#
# We implement Z-standardization as data standardization to correct the scale difference of each characteristic.

# %%
from sklearn.preprocessing import StandardScaler

# Generate instance for standardization
sc = StandardScaler()

# Calculate the transform matrix and it is applied to valid and test data
x_train_std = sc.fit_transform(x_train_win)
x_valid_std = sc.transform(x_valid_win)
x_test_std = sc.transform(x_test_win)

# %% [markdown]
# # 5. LightGBM model for anomaly detection
#
# We construct the LightGBM model to deal with 2 classification problem.
#
# I start by training the model and then fine tuning the hyper parameter like learning rate, max_depth etc.
#
# Finally. we assess the generalization performance using test data.

# %% [markdown]
# **Data  processing for LightGBM**
#
# We implement data processing appropriate for LightGBM model.
#
# When we choose just one TS point as the explanatory variable, we can't reflect the context information of TS into model.
#
# It means the useless predict model.
#
# So, we calculate the stats like mean, min and max within the window area, which is parameterized by look_back.
#
# We assign these stats as the explanatory variable.
#
# Also, we assign the class label at right end of window as the objective variable.
#
# We set look_back=10.
#
# ![4_LIGHTGBMモデル_データ加工_2.png](attachment:1a43d8ad-cacd-4d29-8fca-6c46168cf36d.png)

# %%
#create_dataset function
def create_dataset(dataset,look_back):
    
    data_X=np.zeros((len(dataset)-look_back+1,3))
    j=0
    
    for i in range(look_back-1,len(dataset)):
        
        data_pre=dataset[i-look_back+1:i+1,0]
    
        data_pre_mean=np.mean(data_pre,axis=0)
        data_pre_min=np.min(data_pre,axis=0)
        data_pre_max=np.max(data_pre,axis=0)
        
        data_X[j,:]=np.array([data_pre_mean,data_pre_min,data_pre_max])
        j+=1
    
    return np.array(data_X).reshape(-1,3)  

#window parameter
look_back=10

#Dimension of input data
data_dim=8

for i in range(0,data_dim):
    
    if i==0:
        #train data
        x_train_win=create_dataset(x_train_std[:,i].reshape(-1,1),look_back)
        #valid data
        x_valid_win=create_dataset(x_valid_std[:,i].reshape(-1,1),look_back)
        #test data
        x_test_win=create_dataset(x_test_std[:,i].reshape(-1,1),look_back) 
    else:
        #train data
        x_train_win=np.concatenate([x_train_win,create_dataset( \
                                    x_train_std[:,i].reshape(-1,1),look_back)],axis=-1)
        #valid data
        x_valid_win=np.concatenate([x_valid_win,create_dataset( \
                                    x_valid_std[:,i].reshape(-1,1),look_back)],axis=-1)
        #test data
        x_test_win=np.concatenate([x_test_win,create_dataset( \
                                    x_test_std[:,i].reshape(-1,1),look_back)],axis=-1)
        
#change the shape of data
train_x_win=x_train_win.reshape(-1,3*data_dim)
train_y=y_train[look_back-1:]

valid_x_win=x_valid_win.reshape(-1,3*data_dim)
valid_y=y_valid[look_back-1:]

test_x_win=x_test_win.reshape(-1,3*data_dim)
test_y=y_test[look_back-1:]

#change data type of _x_win from ndarray into dataframe to calculate the importance of characteristic.
features=['A1_mean','A1_min','A1_max', \
          'A2_mean','A2_min','A2_max', \
          'Cur_mean','Cur_min','Cur_max', \
          'Pre_mean','Pre_min','Pre_max', \
          'Temp_mean','Temp_min','Temp_max', \
          'Ther_mean','Ther_min','Ther_max', \
          'Vol_mean','Vol_min','Vol_max', \
          'Flow_mean','Flow_min','Flow_max']

train_x=pd.DataFrame(train_x_win,columns=features)
valid_x=pd.DataFrame(valid_x_win,columns=features)
test_x=pd.DataFrame(test_x_win,columns=features)

# %%
display(train_x)
# Out:
#         A1_mean    A1_min    A1_max   A2_mean    A2_min    A2_max  Cur_mean  \
# 0     -2.679439 -2.865004 -2.451339 -0.692745 -0.766555 -0.560740 -0.023137
# 1     -2.699386 -2.865004 -2.451339 -0.671569 -0.766555 -0.433652 -0.030842
# 2     -2.707761 -2.865004 -2.511303 -0.634760 -0.766555 -0.314949 -0.036504
# 3     -2.696608 -2.865004 -2.399775 -0.577114 -0.766555 -0.129678 -0.039949
# 4     -2.663746 -2.865004 -2.256753 -0.507170 -0.766555 -0.021328 -0.041509
# ...         ...       ...       ...       ...       ...       ...       ...
# 12699  1.382576  1.160770  1.751949 -0.419943 -0.642846 -0.120054 -0.099773
# 12700  1.447580  1.160770  1.920958 -0.358168 -0.642846 -0.001004 -0.102299
# 12701  1.538176  1.160770  2.094342 -0.284097 -0.586892  0.097864 -0.103829
# 12702  1.650044  1.160770  2.303791 -0.210430 -0.549470  0.149778 -0.105232
# 12703  1.778652  1.251157  2.446848 -0.136505 -0.460458  0.189781 -0.105253
#
#         Cur_min   Cur_max  Pre_mean  ...  Temp_max  Ther_mean  Ther_min  \
# 0     -0.057393  0.030316  1.620902  ...  3.284588   2.029763  2.022074
# 1     -0.057393  0.018154  1.330175  ...  3.284588   2.031201  2.023224
# 2     -0.057393  0.008848  0.992358  ...  3.284588   2.032564  2.023664
# 3     -0.057393 -0.011042  0.642892  ...  3.284588   2.033838  2.025164
# 4     -0.057393 -0.025603  0.328793  ...  3.284588   2.034965  2.028704
# ...         ...       ...       ...  ...       ...        ...       ...
# 12699 -0.113770 -0.086471  0.074434  ... -1.614974  -1.195367 -1.197172
# 12700 -0.113770 -0.086471  0.040007  ... -1.621192  -1.195247 -1.197172
# 12701 -0.113770 -0.086471 -0.082566  ... -1.626568  -1.195255 -1.197172
# 12702 -0.113770 -0.094699 -0.271264  ... -1.630165  -1.195310 -1.197172
# 12703 -0.113770 -0.094908 -0.448122  ... -1.634800  -1.195381 -1.197172
#
#        Ther_max  Vol_mean   Vol_min   Vol_max  Flow_mean  Flow_min  Flow_max
# 0      2.037021  0.005519 -0.777578  0.981011   0.415308  0.385021  0.484809
# 1      2.037021 -0.152550 -0.777578  0.910140   0.426186  0.385021  0.493801
# 2      2.037021 -0.278967 -0.777578  0.710646   0.437376  0.385021  0.496921
# 3      2.037021 -0.383274 -0.777578  0.317025   0.453149  0.385021  0.542746
# 4      2.037021 -0.467132 -0.777578 -0.071414   0.469971  0.385021  0.553246
# ...         ...       ...       ...       ...        ...       ...       ...
# 12699 -1.193615  0.474209 -0.239293  1.067034   0.624893  0.562813  0.682260
# 12700 -1.193615  0.331514 -0.359915  0.997815   0.635605  0.562813  0.689802
# 12701 -1.193615  0.199998 -0.359915  0.813437   0.645480  0.583189  0.689802
# 12702 -1.193939  0.099791 -0.359915  0.744264   0.653965  0.594894  0.689802
# 12703 -1.194020  0.011425 -0.359915  0.550573   0.665405  0.643095  0.709296
#
# [12704 rows x 24 columns]

# %% [markdown]
# **Training and fine-tuning**
#
# First of all, we define LightGBM train predict function. We introduce the test_flag as argument for switching train and predict.
# We set early_stopping_rounds=20 to avoid overfitting.
#
# If test_flag = True (test mode), the function returns the accuracy, f1score, confusion matrix for test data and learned model.
#
# If test_flag = False (training mode), it returns the accuracy for train data and valid data.

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix
import random
import tensorflow as tf

# fix random seed
tf.random.set_seed(0)
np.random.seed(0)
random.seed(0)
os.environ["PYTHONHASHSEED"] = "0"

#LightGBM train predict function
def lgb_train_predict(x_train,y_train,x_valid,y_valid,x_test,y_test,params, \
                      test_flag=False):
    
    lgb_train=lgb.Dataset(x_train,y_train)
    lgb_valid=lgb.Dataset(x_valid,y_valid)
    lgb_test=lgb.Dataset(x_test,y_test)
    
    model_lgb=lgb.train(params=params,train_set=lgb_train, \
                        valid_sets=[lgb_train,lgb_valid], \
                        verbose_eval=0,early_stopping_rounds=20)
    
    if test_flag:
        test_pred=np.zeros((len(y_test),1))
        test_pred[:,0]=np.where(model_lgb.predict(x_test)>=0.5,1,0)
        test_acc=accuracy_score(y_test.reshape(-1,1),test_pred)
        test_f1score=f1_score(y_test.reshape(-1,1),test_pred)
        test_cm=confusion_matrix(y_test.reshape(-1,1),test_pred)
        
        return test_acc,test_f1score,test_cm,test_pred,model_lgb
    
    else:
        train_pred=np.zeros((len(y_train),1))
        train_pred[:,0]=np.where(model_lgb.predict(x_train)>=0.5,1,0)
        train_acc=accuracy_score(y_train.reshape(-1,1),train_pred)
        
        valid_pred=np.zeros((len(y_valid),1))
        valid_pred[:,0]=np.where(model_lgb.predict(x_valid)>=0.5,1,0)
        valid_acc=accuracy_score(y_valid.reshape(-1,1),valid_pred) 
        
        return train_acc,valid_acc

# %% [markdown]
# We train the model using the training data(train_x,train_y).
#
# This model needs to be fine-tunned for hyper paramter, so we optimize using the valid_data(valid_x,valid_y).
#
# We implement 100 times random search method for optimizing hyper parameters.

# %%
# Ramdom search for hyper parameter
optimization_trial = 100

results_val_acc = {}
results_train_acc= {}

for _ in range(optimization_trial):
    # =====the searching area of hyper parameter =====
    lr = 10 ** np.random.uniform(-3, 0)
    min_data_in_leaf=np.random.choice(range(1,21),1)[0]
    max_depth=np.random.choice(range(3,31),1)[0]
    num_leaves=np.random.choice(range(20,41),1)[0]
    # ================================================
    
    #Hyper parameter
    lgb_params={'objective':'binary',
                'metric':'binary_error',
                'force_row_wise':True,
                'seed':0,
                'learning_rate':lr,
                'min_data_in_leaf':min_data_in_leaf,
                'max_depth':max_depth,
                'num_leaves':num_leaves
               }

    train_acc,valid_acc=lgb_train_predict(train_x,train_y,valid_x,valid_y,test_x,test_y,params=lgb_params,test_flag=False)
    print('optimization'+str(len(results_val_acc)+1))
    print("train acc:" + str(train_acc) + "valid acc:" + str(valid_acc) + " | lr:" + str(lr) + ", min_data_in_leaf:" + str(min_data_in_leaf) + \
          ",max_depth:" + str(max_depth) + ",num_leaves:" + str(num_leaves))
    key = " lr:" + str(lr) + ", min_data_in_leaf:" + str(min_data_in_leaf) + ", max_depth:" + str(max_depth) + ",num_leaves:" + str(num_leaves)
    results_val_acc[key] = valid_acc
    results_train_acc[key] = train_acc
# Out:
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization1
# train acc:0.955683249370277valid acc:0.9581823250627265 | lr:0.04430375245218265, min_data_in_leaf:1,max_depth:6,num_leaves:23
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization2
# train acc:1.0valid acc:0.9570671870643992 | lr:0.34814103519174666, min_data_in_leaf:20,max_depth:24,num_leaves:38
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization3
# train acc:0.9683564231738035valid acc:0.9556732645664902 | lr:0.020547625125911337, min_data_in_leaf:7,max_depth:27,num_leaves:32
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization4
# train acc:0.9577298488664987valid acc:0.957345971563981 | lr:0.014135935551752292, min_data_in_leaf:7,max_depth:10,num_leaves:34
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization5
# train acc:0.9629250629722922valid acc:0.9576247560635629 | lr:0.05059803874660431, min_data_in_leaf:6,max_depth:28,num_leaves:33
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization6
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.01028462547983763, min_data_in_leaf:20,max_depth:19,num_leaves:39
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization7
# train acc:1.0valid acc:0.9392249790911625 | lr:0.7438159327920402, min_data_in_leaf:16,max_depth:18,num_leaves:20
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization8
# train acc:1.0valid acc:0.9470309450794536 | lr:0.8626905220714904, min_data_in_leaf:18,max_depth:22,num_leaves:39
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization9
# train acc:0.9263224181360201valid acc:0.9562308335656537 | lr:0.10880242882938454, min_data_in_leaf:8,max_depth:3,num_leaves:21
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization10
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.00269190582492607, min_data_in_leaf:1,max_depth:13,num_leaves:40
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization11
# train acc:0.9604848866498741valid acc:0.9581823250627265 | lr:0.026351252231361928, min_data_in_leaf:12,max_depth:21,num_leaves:22
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization12
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0025448050634013252, min_data_in_leaf:5,max_depth:24,num_leaves:25
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization13
# train acc:0.9605636020151134valid acc:0.9592974630610538 | lr:0.06859416411328695, min_data_in_leaf:18,max_depth:18,num_leaves:24
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization14
# train acc:0.9582021410579346valid acc:0.9581823250627265 | lr:0.1110352557719758, min_data_in_leaf:2,max_depth:4,num_leaves:27
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization15
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0015159204611384708, min_data_in_leaf:4,max_depth:9,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization16
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.004277083049962071, min_data_in_leaf:1,max_depth:17,num_leaves:23
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization17
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.012334805700860013, min_data_in_leaf:11,max_depth:23,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization18
# train acc:0.9984256926952141valid acc:0.8500139392249791 | lr:0.9228295957427439, min_data_in_leaf:5,max_depth:18,num_leaves:40
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization19
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.003047393617736387, min_data_in_leaf:5,max_depth:23,num_leaves:28
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization20
# train acc:0.9578872795969773valid acc:0.9576247560635629 | lr:0.01750272884486083, min_data_in_leaf:4,max_depth:29,num_leaves:35
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization21
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0021435095535798543, min_data_in_leaf:17,max_depth:20,num_leaves:25
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization22
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.003888186473153667, min_data_in_leaf:1,max_depth:8,num_leaves:20
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization23
# train acc:0.9570214105793451valid acc:0.9579035405631446 | lr:0.07388193931449268, min_data_in_leaf:5,max_depth:5,num_leaves:36
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization24
# train acc:1.0valid acc:0.9286311681070533 | lr:0.8499206771743678, min_data_in_leaf:3,max_depth:13,num_leaves:33
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization25
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0014694136880098081, min_data_in_leaf:10,max_depth:3,num_leaves:30
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization26
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.007053763390632227, min_data_in_leaf:3,max_depth:28,num_leaves:22
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization27
# train acc:1.0valid acc:0.9548369110677446 | lr:0.43795316349595603, min_data_in_leaf:4,max_depth:21,num_leaves:34
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization28
# train acc:0.9587531486146096valid acc:0.9592974630610538 | lr:0.05009615137983935, min_data_in_leaf:18,max_depth:21,num_leaves:34
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization29
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0019134694478070968, min_data_in_leaf:2,max_depth:7,num_leaves:30
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization30
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.006810134414375388, min_data_in_leaf:9,max_depth:14,num_leaves:22
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization31
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0024853845095262, min_data_in_leaf:1,max_depth:25,num_leaves:20
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization32
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.006225733021242983, min_data_in_leaf:15,max_depth:13,num_leaves:39
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization33
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0011490069048873189, min_data_in_leaf:9,max_depth:16,num_leaves:22
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization34
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.006456897906217104, min_data_in_leaf:3,max_depth:14,num_leaves:33
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization35
# train acc:0.9710327455919395valid acc:0.9567884025648173 | lr:0.019946384472763177, min_data_in_leaf:9,max_depth:22,num_leaves:28
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization36
# train acc:1.0valid acc:0.9422916085865626 | lr:0.487657785915432, min_data_in_leaf:4,max_depth:15,num_leaves:34
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization37
# train acc:0.9726070528967254valid acc:0.9567884025648173 | lr:0.022263488451764367, min_data_in_leaf:4,max_depth:16,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization38
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.007803884850277907, min_data_in_leaf:14,max_depth:28,num_leaves:33
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization39
# train acc:0.966624685138539valid acc:0.9592974630610538 | lr:0.10624713883091959, min_data_in_leaf:17,max_depth:27,num_leaves:34
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization40
# train acc:0.9847292191435768valid acc:0.9514914970727627 | lr:0.11956244022128876, min_data_in_leaf:20,max_depth:4,num_leaves:28
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization41
# train acc:0.9577298488664987valid acc:0.957345971563981 | lr:0.01868809984193789, min_data_in_leaf:7,max_depth:24,num_leaves:33
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization42
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.007310936521630819, min_data_in_leaf:16,max_depth:12,num_leaves:38
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization43
# train acc:0.9734729219143576valid acc:0.9344856425982715 | lr:0.4318735144349634, min_data_in_leaf:16,max_depth:14,num_leaves:26
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization44
# train acc:0.9629250629722922valid acc:0.9576247560635629 | lr:0.05127370874628439, min_data_in_leaf:2,max_depth:25,num_leaves:32
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization45
# train acc:1.0valid acc:0.9316977976024533 | lr:0.8070218545326339, min_data_in_leaf:4,max_depth:21,num_leaves:35
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization46
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.002653332733131654, min_data_in_leaf:13,max_depth:9,num_leaves:23
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization47
# train acc:1.0valid acc:0.9545581265681629 | lr:0.47399096676561264, min_data_in_leaf:6,max_depth:26,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization48
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.001998391905573771, min_data_in_leaf:9,max_depth:23,num_leaves:30
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization49
# train acc:0.9575724181360201valid acc:0.9576247560635629 | lr:0.025570988797875227, min_data_in_leaf:6,max_depth:18,num_leaves:28
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization50
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0030724074111466446, min_data_in_leaf:20,max_depth:28,num_leaves:39
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# ...
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization77
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0028912318204657684, min_data_in_leaf:14,max_depth:8,num_leaves:20
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization78
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.004412068131729174, min_data_in_leaf:16,max_depth:24,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization79
# train acc:0.9694584382871536valid acc:0.9523278505715083 | lr:0.3904512502173688, min_data_in_leaf:14,max_depth:29,num_leaves:30
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization80
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0024900285064657587, min_data_in_leaf:18,max_depth:30,num_leaves:39
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization81
# train acc:0.9615869017632241valid acc:0.9581823250627265 | lr:0.024516055732776224, min_data_in_leaf:19,max_depth:24,num_leaves:22
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization82
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.002719839508265555, min_data_in_leaf:12,max_depth:26,num_leaves:38
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization83
# train acc:0.9671756926952141valid acc:0.9559520490660719 | lr:0.17417375729910842, min_data_in_leaf:2,max_depth:9,num_leaves:30
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization84
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0017793742700293234, min_data_in_leaf:17,max_depth:29,num_leaves:23
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization85
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.007523892475314567, min_data_in_leaf:11,max_depth:12,num_leaves:32
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization86
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0015456632066963682, min_data_in_leaf:7,max_depth:9,num_leaves:27
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization87
# train acc:0.9670182619647355valid acc:0.9562308335656537 | lr:0.10227032587087773, min_data_in_leaf:8,max_depth:19,num_leaves:35
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization88
# train acc:0.9642632241813602valid acc:0.9587398940618902 | lr:0.03444929907153382, min_data_in_leaf:4,max_depth:9,num_leaves:37
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization89
# train acc:1.0valid acc:0.9520490660719264 | lr:0.4261041224885884, min_data_in_leaf:3,max_depth:19,num_leaves:38
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# optimization90
# train acc:1.0valid acc:0.944800669082799 | lr:0.70462243557644, min_data_in_leaf:5,max_depth:7,num_leaves:32
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization91
# train acc:0.9624527707808564valid acc:0.9587398940618902 | lr:0.07786527300043783, min_data_in_leaf:2,max_depth:8,num_leaves:21
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization92
# train acc:1.0valid acc:0.954279342068581 | lr:0.38630411293369415, min_data_in_leaf:20,max_depth:25,num_leaves:27
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization93
# train acc:0.9603274559193955valid acc:0.9581823250627265 | lr:0.03105804368610554, min_data_in_leaf:10,max_depth:25,num_leaves:20
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization94
# train acc:0.9669395465994962valid acc:0.9556732645664902 | lr:0.01704026774312867, min_data_in_leaf:5,max_depth:20,num_leaves:40
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization95
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0037114510384916306, min_data_in_leaf:4,max_depth:13,num_leaves:21
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization96
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0019657733972691877, min_data_in_leaf:5,max_depth:19,num_leaves:36
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization97
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.010735357448471379, min_data_in_leaf:14,max_depth:11,num_leaves:31
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization98
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.009987009341166649, min_data_in_leaf:7,max_depth:12,num_leaves:35
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization99
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.002497255074340221, min_data_in_leaf:13,max_depth:21,num_leaves:37
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# optimization100
# train acc:0.6608154911838791valid acc:0.6662949540005576 | lr:0.0011011467157144889, min_data_in_leaf:2,max_depth:14,num_leaves:23

# %% [markdown]
# We plot the random search result. Show best5 of 100 times result.

# %%
print("=========== Hyper-Parameter Optimization Result ===========")
i = 0
for key, val_acc in sorted(results_val_acc.items(), key=lambda x:x[1], reverse=True):
    
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc) + ")| " + key)
    i += 1

    if i >= int(optimization_trial*0.05):
        break
# Out:
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.9595762475606356)|  lr:0.04241273949596576, min_data_in_leaf:15, max_depth:24,num_leaves:29
# Best-2(val acc:0.9595762475606356)|  lr:0.06624226646887021, min_data_in_leaf:18, max_depth:12,num_leaves:20
# Best-3(val acc:0.9592974630610538)|  lr:0.06859416411328695, min_data_in_leaf:18, max_depth:18,num_leaves:24
# Best-4(val acc:0.9592974630610538)|  lr:0.05009615137983935, min_data_in_leaf:18, max_depth:21,num_leaves:34
# Best-5(val acc:0.9592974630610538)|  lr:0.10624713883091959, min_data_in_leaf:17, max_depth:27,num_leaves:34

# %% [markdown]
# **Evaluating the generalization performance for test data**
#
# We construct the model with fine-tunned hyperparameter using training data.
# When we predict anomaly for test data, we calculate the accuracy, F1score and confusion matrix.

# %%
#fine-tunned hyper paramter
lgb_params={'objective':'binary',
            'metric':'binary_error',
            'force_row_wise':True,
            'seed':0,
            'learning_rate':0.0424127,
            'min_data_in_leaf':15,
            'max_depth':24,
            'num_leaves':29
           }

test_acc,test_f1score,test_cm,test_pred,model_lgb=lgb_train_predict(train_x,train_y,valid_x,valid_y,test_x,test_y,params=lgb_params,test_flag=True)

print('test_acc:' + str(test_acc))
print('test_f1score:' + str(test_f1score))
print('test_confusionMatrix')
display(test_cm)

plt.figure(figsize=(10,5))
plt.plot(range(len(test_y)),test_y,linestyle='none', marker='X', color='blue', markersize=5, label='Anomaly')
plt.plot(range(len(test_pred)),test_pred,linestyle='none', marker='X', color='red', markersize=5, label='Predict',alpha=0.05)
plt.title('Light GBM')
plt.xlabel('index')
plt.ylabel('label')
plt.legend(loc='best')
# Out:
# [LightGBM] [Info] Number of positive: 4309, number of negative: 8395
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 12704, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.339185 -> initscore=-0.666930
# [LightGBM] [Info] Start training from score -0.666930
# test_acc:0.9197396963123644
# test_f1score:0.8984910836762688
# test_confusionMatrix
# array([[1041,    0],
#        [ 148,  655]])

# %% [markdown]
# We can predict the class of test data for around 90 percent.

# %% [markdown]
# To give the explainability to model, we calculate the importance of characteristic.
#
# It means the index of how much each characteristic contributes to the classification.
#
# We use the model with the fine tunned hyperparameter for evaluating the importance.

# %%
lgb.plot_importance(model_lgb,height=0.5,figsize=(4,8))
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# ## Data Augmentation

# %%
from imblearn.combine import SMOTEENN

# Data augmentation using SMOTEENN
smoteenn = SMOTEENN(random_state=0)
train_x_aug, train_y_aug = smoteenn.fit_resample(train_x, train_y)

# %%
test_acc,test_f1score,test_cm,test_pred,model_lgb1=lgb_train_predict(train_x_aug,train_y_aug,valid_x,valid_y,test_x,test_y,params=lgb_params,test_flag=True)

print('test_acc:' + str(test_acc))
print('test_f1score:' + str(test_f1score))
print('test_confusionMatrix')
display(test_cm)

plt.figure(figsize=(10,5))
plt.plot(range(len(test_y)),test_y,linestyle='none', marker='X', color='blue', markersize=5, label='Anomaly')
plt.plot(range(len(test_pred)),test_pred,linestyle='none', marker='X', color='red', markersize=5, label='Predict',alpha=0.05)
plt.title('Light GBM')
plt.xlabel('index')
plt.ylabel('label')
plt.legend(loc='best')
# Out:
# [LightGBM] [Info] Number of positive: 8364, number of negative: 8300
# [LightGBM] [Info] Total Bins 6120
# [LightGBM] [Info] Number of data points in the train set: 16664, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.501920 -> initscore=0.007681
# [LightGBM] [Info] Start training from score 0.007681
# test_acc:0.9202819956616052
# test_f1score:0.8992460589444825
# test_confusionMatrix
# array([[1041,    0],
#        [ 147,  656]])

# %% [markdown]
# ## FreaAI

# %%
new_train_x = train_x.copy()
new_val_x = valid_x.copy()
new_test_x = test_x.copy()
counter = 0

# %%
from freaAI import run_data_search, clean_output

XX = train_x
YY = train_y


pred_y = model_lgb.predict(XX)
predictions = [round(value) for value in pred_y]
accuracy_bool = (np.array(YY).flatten() ==  np.array(predictions))
x_freaai = XX.copy()
x_freaai["accuracy_bool"] = accuracy_bool

a, b, c = run_data_search(x_freaai, 1, False, False, True)
out2 = clean_output(a,b,c)
out2.dropna(inplace=True)
# Out:
# Running: DT for Cur_min and Cur_mean
# Running: DT for Cur_min and A2_min
# Running: DT for Cur_min and Flow_max
# Running: DT for Cur_min and A1_max
# Running: DT for Cur_min and Ther_max
# Running: DT for Cur_min and Ther_min
# Running: DT for Cur_min and Temp_max
# Running: DT for Cur_min and Flow_mean
# Running: DT for Cur_min and Temp_min
# Running: DT for Cur_min and Vol_max
# Running: DT for Cur_min and A1_min
# Running: DT for Cur_min and Pre_max
# Running: DT for Cur_min and Flow_min
# Running: DT for Cur_min and A2_mean
# Running: DT for Cur_min and Vol_min
# Running: DT for Cur_min and Pre_min
# Running: DT for Cur_min and Cur_max
# Running: DT for Cur_min and A1_mean
# Running: DT for Cur_min and A2_max
# Running: DT for Cur_min and Temp_mean
# Running: DT for Cur_min and Pre_mean
# Running: DT for Cur_min and Ther_mean
# Running: DT for Cur_min and Vol_mean
# Running: DT for Cur_mean and A2_min
# Running: DT for Cur_mean and Flow_max
# Running: DT for Cur_mean and A1_max
# Running: DT for Cur_mean and Ther_max
# Running: DT for Cur_mean and Ther_min
# Running: DT for Cur_mean and Temp_max
# Running: DT for Cur_mean and Flow_mean
# Running: DT for Cur_mean and Temp_min
# Running: DT for Cur_mean and Vol_max
# Running: DT for Cur_mean and A1_min
# Running: DT for Cur_mean and Pre_max
# Running: DT for Cur_mean and Flow_min
# Running: DT for Cur_mean and A2_mean
# Running: DT for Cur_mean and Vol_min
# Running: DT for Cur_mean and Pre_min
# Running: DT for Cur_mean and Cur_max
# Running: DT for Cur_mean and A1_mean
# Running: DT for Cur_mean and A2_max
# Running: DT for Cur_mean and Temp_mean
# Running: DT for Cur_mean and Pre_mean
# Running: DT for Cur_mean and Ther_mean
# Running: DT for Cur_mean and Vol_mean
# Running: DT for A2_min and Flow_max
# Running: DT for A2_min and A1_max
# Running: DT for A2_min and Ther_max
# Running: DT for A2_min and Ther_min
# Running: DT for A2_min and Temp_max
# Running: DT for A2_min and Flow_mean
# Running: DT for A2_min and Temp_min
# Running: DT for A2_min and Vol_max
# Running: DT for A2_min and A1_min
# Running: DT for A2_min and Pre_max
# Running: DT for A2_min and Flow_min
# Running: DT for A2_min and A2_mean
# Running: DT for A2_min and Vol_min
# Running: DT for A2_min and Pre_min
# Running: DT for A2_min and Cur_max
# Running: DT for A2_min and A1_mean
# Running: DT for A2_min and A2_max
# Running: DT for A2_min and Temp_mean
# Running: DT for A2_min and Pre_mean
# Running: DT for A2_min and Ther_mean
# Running: DT for A2_min and Vol_mean
# Running: DT for Flow_max and A1_max
# Running: DT for Flow_max and Ther_max
# Running: DT for Flow_max and Ther_min
# Running: DT for Flow_max and Temp_max
# Running: DT for Flow_max and Flow_mean
# Running: DT for Flow_max and Temp_min
# Running: DT for Flow_max and Vol_max
# Running: DT for Flow_max and A1_min
# Running: DT for Flow_max and Pre_max
# Running: DT for Flow_max and Flow_min
# Running: DT for Flow_max and A2_mean
# Running: DT for Flow_max and Vol_min
# Running: DT for Flow_max and Pre_min
# Running: DT for Flow_max and Cur_max
# Running: DT for Flow_max and A1_mean
# Running: DT for Flow_max and A2_max
# Running: DT for Flow_max and Temp_mean
# Running: DT for Flow_max and Pre_mean
# Running: DT for Flow_max and Ther_mean
# Running: DT for Flow_max and Vol_mean
# Running: DT for A1_max and Ther_max
# Running: DT for A1_max and Ther_min
# Running: DT for A1_max and Temp_max
# Running: DT for A1_max and Flow_mean
# Running: DT for A1_max and Temp_min
# Running: DT for A1_max and Vol_max
# Running: DT for A1_max and A1_min
# Running: DT for A1_max and Pre_max
# Running: DT for A1_max and Flow_min
# Running: DT for A1_max and A2_mean
# Running: DT for A1_max and Vol_min
# Running: DT for A1_max and Pre_min
# Running: DT for A1_max and Cur_max
# Running: DT for A1_max and A1_mean
# Running: DT for A1_max and A2_max
# Running: DT for A1_max and Temp_mean
# Running: DT for A1_max and Pre_mean
# Running: DT for A1_max and Ther_mean
# Running: DT for A1_max and Vol_mean
# Running: DT for Ther_max and Ther_min
# Running: DT for Ther_max and Temp_max
# Running: DT for Ther_max and Flow_mean
# Running: DT for Ther_max and Temp_min
# Running: DT for Ther_max and Vol_max
# Running: DT for Ther_max and A1_min
# Running: DT for Ther_max and Pre_max
# Running: DT for Ther_max and Flow_min
# Running: DT for Ther_max and A2_mean
# Running: DT for Ther_max and Vol_min
# Running: DT for Ther_max and Pre_min
# Running: DT for Ther_max and Cur_max
# Running: DT for Ther_max and A1_mean
# Running: DT for Ther_max and A2_max
# Running: DT for Ther_max and Temp_mean
# Running: DT for Ther_max and Pre_mean
# Running: DT for Ther_max and Ther_mean
# Running: DT for Ther_max and Vol_mean
# Running: DT for Ther_min and Temp_max
# Running: DT for Ther_min and Flow_mean
# Running: DT for Ther_min and Temp_min
# Running: DT for Ther_min and Vol_max
# Running: DT for Ther_min and A1_min
# Running: DT for Ther_min and Pre_max
# Running: DT for Ther_min and Flow_min
# Running: DT for Ther_min and A2_mean
# Running: DT for Ther_min and Vol_min
# Running: DT for Ther_min and Pre_min
# Running: DT for Ther_min and Cur_max
# Running: DT for Ther_min and A1_mean
# Running: DT for Ther_min and A2_max
# Running: DT for Ther_min and Temp_mean
# Running: DT for Ther_min and Pre_mean
# Running: DT for Ther_min and Ther_mean
# Running: DT for Ther_min and Vol_mean
# Running: DT for Temp_max and Flow_mean
# Running: DT for Temp_max and Temp_min
# Running: DT for Temp_max and Vol_max
# Running: DT for Temp_max and A1_min
# Running: DT for Temp_max and Pre_max
# Running: DT for Temp_max and Flow_min
# Running: DT for Temp_max and A2_mean
# Running: DT for Temp_max and Vol_min
# Running: DT for Temp_max and Pre_min
# Running: DT for Temp_max and Cur_max
# Running: DT for Temp_max and A1_mean
# Running: DT for Temp_max and A2_max
# Running: DT for Temp_max and Temp_mean
# Running: DT for Temp_max and Pre_mean
# Running: DT for Temp_max and Ther_mean
# Running: DT for Temp_max and Vol_mean
# Running: DT for Flow_mean and Temp_min
# Running: DT for Flow_mean and Vol_max
# Running: DT for Flow_mean and A1_min
# Running: DT for Flow_mean and Pre_max
# Running: DT for Flow_mean and Flow_min
# Running: DT for Flow_mean and A2_mean
# Running: DT for Flow_mean and Vol_min
# Running: DT for Flow_mean and Pre_min
# Running: DT for Flow_mean and Cur_max
# Running: DT for Flow_mean and A1_mean
# Running: DT for Flow_mean and A2_max
# Running: DT for Flow_mean and Temp_mean
# Running: DT for Flow_mean and Pre_mean
# Running: DT for Flow_mean and Ther_mean
# Running: DT for Flow_mean and Vol_mean
# Running: DT for Temp_min and Vol_max
# Running: DT for Temp_min and A1_min
# Running: DT for Temp_min and Pre_max
# Running: DT for Temp_min and Flow_min
# Running: DT for Temp_min and A2_mean
# Running: DT for Temp_min and Vol_min
# Running: DT for Temp_min and Pre_min
# Running: DT for Temp_min and Cur_max
# Running: DT for Temp_min and A1_mean
# Running: DT for Temp_min and A2_max
# Running: DT for Temp_min and Temp_mean
# Running: DT for Temp_min and Pre_mean
# Running: DT for Temp_min and Ther_mean
# Running: DT for Temp_min and Vol_mean
# Running: DT for Vol_max and A1_min
# Running: DT for Vol_max and Pre_max
# Running: DT for Vol_max and Flow_min
# Running: DT for Vol_max and A2_mean
# Running: DT for Vol_max and Vol_min
# Running: DT for Vol_max and Pre_min
# Running: DT for Vol_max and Cur_max
# Running: DT for Vol_max and A1_mean
# Running: DT for Vol_max and A2_max
# Running: DT for Vol_max and Temp_mean
# Running: DT for Vol_max and Pre_mean
# Running: DT for Vol_max and Ther_mean
# Running: DT for Vol_max and Vol_mean
# Running: DT for A1_min and Pre_max
# Running: DT for A1_min and Flow_min
# Running: DT for A1_min and A2_mean
# Running: DT for A1_min and Vol_min
# Running: DT for A1_min and Pre_min
# Running: DT for A1_min and Cur_max
# Running: DT for A1_min and A1_mean
# Running: DT for A1_min and A2_max
# Running: DT for A1_min and Temp_mean
# Running: DT for A1_min and Pre_mean
# Running: DT for A1_min and Ther_mean
# Running: DT for A1_min and Vol_mean
# Running: DT for Pre_max and Flow_min
# Running: DT for Pre_max and A2_mean
# Running: DT for Pre_max and Vol_min
# Running: DT for Pre_max and Pre_min
# Running: DT for Pre_max and Cur_max
# Running: DT for Pre_max and A1_mean
# Running: DT for Pre_max and A2_max
# Running: DT for Pre_max and Temp_mean
# Running: DT for Pre_max and Pre_mean
# Running: DT for Pre_max and Ther_mean
# Running: DT for Pre_max and Vol_mean
# Running: DT for Flow_min and A2_mean
# Running: DT for Flow_min and Vol_min
# Running: DT for Flow_min and Pre_min
# Running: DT for Flow_min and Cur_max
# Running: DT for Flow_min and A1_mean
# Running: DT for Flow_min and A2_max
# Running: DT for Flow_min and Temp_mean
# Running: DT for Flow_min and Pre_mean
# Running: DT for Flow_min and Ther_mean
# Running: DT for Flow_min and Vol_mean
# Running: DT for A2_mean and Vol_min
# Running: DT for A2_mean and Pre_min
# Running: DT for A2_mean and Cur_max
# Running: DT for A2_mean and A1_mean
# Running: DT for A2_mean and A2_max
# Running: DT for A2_mean and Temp_mean
# Running: DT for A2_mean and Pre_mean
# Running: DT for A2_mean and Ther_mean
# Running: DT for A2_mean and Vol_mean
# Running: DT for Vol_min and Pre_min
# Running: DT for Vol_min and Cur_max
# Running: DT for Vol_min and A1_mean
# Running: DT for Vol_min and A2_max
# Running: DT for Vol_min and Temp_mean
# Running: DT for Vol_min and Pre_mean
# Running: DT for Vol_min and Ther_mean
# Running: DT for Vol_min and Vol_mean
# Running: DT for Pre_min and Cur_max
# Running: DT for Pre_min and A1_mean
# Running: DT for Pre_min and A2_max
# Running: DT for Pre_min and Temp_mean
# Running: DT for Pre_min and Pre_mean
# Running: DT for Pre_min and Ther_mean
# Running: DT for Pre_min and Vol_mean
# Running: DT for Cur_max and A1_mean
# Running: DT for Cur_max and A2_max
# Running: DT for Cur_max and Temp_mean
# Running: DT for Cur_max and Pre_mean
# Running: DT for Cur_max and Ther_mean
# Running: DT for Cur_max and Vol_mean
# Running: DT for A1_mean and A2_max
# Running: DT for A1_mean and Temp_mean
# Running: DT for A1_mean and Pre_mean
# Running: DT for A1_mean and Ther_mean
# Running: DT for A1_mean and Vol_mean
# Running: DT for A2_max and Temp_mean
# Running: DT for A2_max and Pre_mean
# Running: DT for A2_max and Ther_mean
# Running: DT for A2_max and Vol_mean
# Running: DT for Temp_mean and Pre_mean
# Running: DT for Temp_mean and Ther_mean
# Running: DT for Temp_mean and Vol_mean
# Running: DT for Pre_mean and Ther_mean
# Running: DT for Pre_mean and Vol_mean
# Running: DT for Ther_mean and Vol_mean

# %%
new_train_x = train_x.copy()
new_val_x = valid_x.copy()
new_test_x = test_x.copy()
counter = 0

cols = []
for x,y,acc in zip(out2["names"], out2["indicies"], out2["accuracies"]):
#     if acc[0] > 0.8:
#         continue
#     print(acc[0])
#     print(len(x))
#     print(len(y), "XXX")
    for i in range(len(y)):
        col1 = x.split("-")[0]
        col2 = x.split("-")[1]
        z = XX[col1].iloc[y[i]]
        min_value1 = z.min()
        max_value1 = z.max()

        z = XX[col2].iloc[y[i]]
        min_value2 = z.min()
        max_value2 = z.max()

        print(col1, col2, min_value1, max_value1, min_value2, max_value2)
    #     break

        new_col = "x" + str(counter)
        cols.append(new_col)
        print(new_col)
        counter += 1
#         if new_col != "x3":
#             continue

        new_train_x[new_col] = 0
    #     new_train_x[new_col].iloc[np.logical_and(new_train_x[col]>=min_value, new_train_x[col]<=max_value)] = 1
        x1 = new_train_x[col1] >= min_value1
        x2 = new_train_x[col1] <= max_value1

        x3 = new_train_x[col2] >= min_value2
        x4 = new_train_x[col2] <= max_value2
        new_train_x[new_col].iloc[new_train_x[x1][x2][x3][x4].index.to_numpy()] = 1


        new_val_x[new_col] = 0
    #     new_val_x[new_col].iloc[np.logical_and(new_val_x[col]>=min_value, new_val_x[col]<=max_value)] = 1
        x1 = new_val_x[col1] >= min_value1
        x2 = new_val_x[col1] <= max_value1
        x3 = new_val_x[col2] >= min_value2
        x4 = new_val_x[col2] <= max_value2

    #     print(new_val_x[x1][x2][x3][x4].index.to_numpy())
        new_val_x[new_col].iloc[new_val_x[x1][x2][x3][x4].index.to_numpy()] = 1

        new_test_x[new_col] = 0
        x1 = new_test_x[col1] >= min_value1
        x2 = new_test_x[col1] <= max_value1
        x3 = new_test_x[col2] >= min_value2
        x4 = new_test_x[col2] <= max_value2
        new_test_x[new_col].iloc[new_test_x[x1][x2][x3][x4].index.to_numpy()] = 1
        
#         if new_test_x[new_col].unique().shape[0] != 2:
#             new_train_x.drop(new_col, axis=1, inplace=True)
#             new_val_x.drop(new_col, axis=1, inplace=True)
#             new_test_x.drop(new_col, axis=1, inplace=True)
#             print("not ok")
#         else:
#             print("ok")
    
#     new_test_x[new_col].iloc[np.logical_and(new_test_x[col]>=min_value, new_test_x[col]<=max_value)] = 1
#     new
# Out:
# Cur_max A2_max -0.21638353912006683 11.296108547300697 -1.6670553417395664 -1.1740254787389786
# x0
# Cur_max A2_max 11.31198239380685 11.347009569407701 -0.9625914798488021 0.4354878221405
# x1
# Cur_max A2_max 11.809957512933991 11.809957512933991 0.8438679546279616 0.9149456563608436
# x2
# Cur_mean Cur_max -0.1771888309522937 -0.13632286879143915 -0.17292048553535927 -0.12712242760447948
# x3
# Cur_mean Cur_max 5.210511608004405 8.962181002895557 11.31198239380685 11.347009569407701
# x4
# Cur_mean Cur_max 6.646970709905803 9.33936415719963 11.809957512933991 11.809957512933991
# x5
# Ther_max Cur_max -0.1406990433671613 1.3665038254065678 11.31198239380685 11.809957512933991
# x6
# Ther_max Cur_max 1.7286730053175203 1.7458567461279537 11.347009569407701 11.347009569407701
# x7
# Cur_min Cur_max -0.19769007296945526 4.949899886902767 11.31198239380685 11.347009569407701
# x8
# Cur_min Cur_max -0.06649517371749862 5.135404232215449 11.809957512933991 11.809957512933991
# x9
# Vol_max Cur_max -1.357288244237273 3.4118849347397653 -0.15645394288609368 -0.12712242760447948
# x10
# Vol_max Cur_max -3.837670718703486 1.058208747158575 11.31198239380685 11.347009569407701
# x11
# Vol_max Cur_max -3.109267006083777 0.7282084211920553 11.809957512933991 11.809957512933991
# x12
# A2_min Cur_max -1.9985355194764514 0.24439873101908371 -0.2477090118110492 -0.12712242760447948
# x13
# A2_min Cur_max -1.9985355194764514 -1.8081588286427202 -0.12540106465424114 11.021394742749417
# x14
# A2_min Cur_max -1.7858290626232056 -0.24105999489290247 11.31198239380685 11.347009569407701
# x15
# A2_min Cur_max 0.3521963439087813 0.7641861094045773 11.809957512933991 11.809957512933991
# x16
# Cur_max Vol_mean -0.15645394288609368 -0.12712242760447948 -2.0683082719405275 2.73750600499167
# x17
# Cur_max Vol_mean 11.31198239380685 11.61095469770304 -5.493066367078893 -1.5484989281281751
# x18
# Cur_max Vol_mean 11.809957512933991 11.809957512933991 -4.569064337127804 -2.2032754137270034
# x19
# A1_max Cur_max -2.7296312484110814 -1.5244572635129117 -0.2237110932246147 11.021394742749417
# x20
# A1_max Cur_max -1.5238238679282836 -1.5238238679282836 -0.1523438343378104 -0.12929302795119144
# x21
# A1_max Cur_max -1.732907873688395 -1.4712445701000747 11.347009569407701 11.347009569407701
# x22
# A1_max Cur_max -1.2205201213964525 1.137506757271493 11.31198239380685 11.61095469770304
# x23
# A1_max Cur_max 0.4631814170750355 0.5078516471419002 11.809957512933991 11.809957512933991
# x24
# Cur_max A1_mean -0.2237110932246147 -0.12735813244355057 -2.8263536154634807 -1.5733700658748535
# x25
# Cur_max A1_mean 11.347009569407701 11.347009569407701 -1.9572233359877003 -1.5779501701241654
# x26
# Cur_max A1_mean 11.31198239380685 11.61095469770304 -1.4008705427270294 1.0597093215565512
# x27
# Cur_max A1_mean 11.809957512933991 11.809957512933991 0.336384944703051 0.4320699812515099
# x28
# Vol_min Cur_max -2.7751497667930995 1.451144645848059 -0.15645394288609368 -0.12712242760447948
# x29
# Vol_min Cur_max -7.13633031458856 -7.13633031458856 11.31198239380685 11.31198239380685
# x30
# Vol_min Cur_max -7.443484860686866 -7.1077355400883775 11.347009569407701 11.347009569407701
# x31
# Vol_min Cur_max -5.35523100281862 -5.35523100281862 11.809957512933991 11.809957512933991
# x32
# A1_min Cur_max -3.0729378920587016 1.649245143452078 -0.15645394288609368 -0.12712242760447948
# x33
# A1_min Cur_max -2.1528616730194923 -1.732907873688395 11.347009569407701 11.347009569407701
# x34
# A1_min Cur_max -1.4877236933309201 1.010918026700947 11.31198239380685 11.61095469770304
# x35
# A1_min Cur_max 0.2025527350040435 0.3712538090929522 11.809957512933991 11.809957512933991
# x36
# Flow_mean Cur_max -0.05936833403643952 1.0022701628019122 -0.2477090118110492 -0.12712242760447948
# x37
# Flow_mean Cur_max 0.056135344294519295 0.5902690522427007 11.31198239380685 11.809957512933991
# x38
# Flow_max Cur_max -0.04386279299775875 1.0573441060906172 -0.2477090118110492 -0.12468739822081758
# x39
# Flow_max Cur_max 0.29762264878765265 0.695233687659056 11.31198239380685 11.809957512933991
# x40
# Flow_min Cur_max -0.10431897283106706 -0.02997398875689405 -0.22319237172547615 -0.15285268472885233
# x41
# Flow_min Cur_max -0.10335788437591137 -0.028119943440562862 -0.15229851868764188 11.809957512933991
# x42
# Flow_min Cur_max 0.057444553437952704 0.6401557902808621 11.31198239380685 11.809957512933991
# x43
# Cur_min A1_min -0.24101839412421375 -0.06416385447993812 -2.2252930322362867 -1.7120428676955537
# x44
# Cur_min A1_min 4.865170906769863 5.135404232215449 -2.0007719652491525 0.2820490116950158
# x45
# Cur_min A1_mean -0.24982649694942702 -0.06387272428465046 -2.165334986221428 -1.5733700658748535
# x46
# Cur_min A1_mean 4.865170906769863 5.135404232215449 -1.752632323655794 0.41812343569216204
# x47
# Cur_min Pre_min -0.26365602735090965 -0.06714941111611802 -2.419136178403997 -2.309685414336755
# x48
# Cur_min Pre_min 4.865170906769863 5.135404232215449 -0.7377914189204227 0.5547417040375173
# x49
# Cur_min Pre_mean -0.27514896423069996 -0.24604031450931876 -2.3846807388122544 2.1283711494223345
# x50
# Cur_min Pre_mean -0.19392911868377344 -0.19392911868377344 -0.1840206282076189 0.9425760412006772
# x51
# Cur_min Pre_mean 4.865170906769863 5.135404232215449 -0.17550334127837752 1.0232186247377224
# x52
# Ther_min Cur_max -1.191820604732019 -1.191820604732019 -0.0955604203175335 -0.046876463321601655
# x53
# Ther_min Cur_max -0.1568972484507915 0.3308632998284844 11.31198239380685 11.809957512933991
# x54
# Ther_min Cur_max 0.3313914522996187 1.7286730053175203 11.31198239380685 11.61095469770304
# x55
# Cur_max Ther_mean 11.31198239380685 11.809957512933991 -0.1465188184110292 0.3415800834766041
# x56
# Cur_max Ther_mean 11.31198239380685 11.61095469770304 0.3440617442067975 1.7408042364462488
# x57
# Ther_max A1_min 1.7188604449999048 1.9714863230026713 -2.2252930322362867 -1.230100186215051
# x58
# Ther_max A1_min 1.9724518906034276 2.1697408221263825 -2.2110541797678285 -1.6202608397554765
# x59
# Cur_min Vol_min 4.922213363385448 5.135404232215449 -7.2756434129861765 -5.248619361051382
# x60
# Temp_max Cur_max -1.0721332007655113 -1.0613027356625888 -0.19785874999895858 0.014449637626966487
# x61
# Temp_max Cur_max -0.7209660553367258 -0.7095017888340749 -0.20313911020800485 0.04869267518713961
# x62
# Temp_max Cur_max -0.7092425961835065 -0.7087437141728019 -0.16826484019098556 -0.022971570042705905
# x63
# Temp_max Cur_max -0.5852209930739113 1.6255015846050571 11.31198239380685 11.809957512933991
# x64
# Cur_max Temp_mean -0.21213575909590862 0.014449637626966487 -1.0783061435159829 -1.0680852914608088
# x65
# Cur_max Temp_mean -0.20313911020800485 -0.07346602009992804 -0.7251798476920435 -0.7129548385971533
# x66
# Cur_max Temp_mean -0.07150211864754835 0.039777468829631825 -0.7249193474413557 -0.7127578604048763
# x67
# Cur_max Temp_mean 11.31198239380685 11.809957512933991 -0.589876455115847 1.6146530304305475
# x68
# Temp_min Cur_max -1.0823847087861216 -1.0783908725303504 -0.19560171082452849 0.01099873443357096
# x69
# Temp_min Cur_max -0.7301861150343376 -0.7252779535812269 -0.20313911020800485 8.140040571280187
# x70
# Temp_min Cur_max -0.7250376341017942 -0.716647536538349 -0.2019093002256457 9.472723870169464
# x71
# Temp_min Cur_max -0.5933239605686691 1.6044245917159916 11.31198239380685 11.809957512933991
# x72
# A2_min Temp_min -1.263746102719016 0.1292180741632937 -1.0823847087861216 -1.0783908725303504
# x73
# A2_min Temp_min -1.6013133336710137 0.05625098704317866 -0.7301861150343376 -0.716647536538349
# x74
# A2_min Temp_min 1.617293676970091 2.3625970002981433 -0.7165367994358494 0.08048508026375385
# x75
# Temp_min A2_max -1.0823847087861216 -1.0783908725303504 -0.18906646205201919 1.1295948346857272
# x76
# Temp_min A2_max -0.7301861150343376 -0.716647536538349 -1.362349161316002 1.0011400337935832
# x77
# Temp_min A2_max -0.7165367994358494 0.10237777535747872 2.3016344401107096 2.98420517384683
# x78
# Cur_min Cur_mean -0.2273077453341964 -0.08197975222394442 5.210511608004405 8.281370397642355
# x79
# Cur_min Cur_mean -0.07618514507217282 -0.06649517371749862 5.496856393912886 8.614309672608805
# x80
# Cur_min Cur_mean 4.84124916212325 5.135404232215449 8.950352829968663 9.33936415719963
# x81
# Temp_min A2_mean -1.0823847087861216 -1.0783908725303504 -0.9106992344981725 0.7065756893789962
# x82
# Temp_min A2_mean -0.7301861150343376 -0.716647536538349 -1.455189525768585 0.8311544535698052
# x83
# Temp_min A2_mean -0.7165367994358494 0.09296935026968564 1.7309622960018465 2.561890432631296
# x84
# A2_max Temp_mean -0.42984186248476103 1.1295948346857272 -1.0783061435159829 -1.0680852914608088
# x85
# A2_max Temp_mean -1.3919001412739767 1.0011400337935832 -0.7251798476920435 -0.7127578604048763
# x86
# A2_max Temp_mean 2.3016344401107096 3.2244827465363226 -0.710961052157576 0.11802804185170068
# x87
# A2_min Temp_mean -1.263746102719016 0.33620269251124757 -1.0783061435159829 -1.0680852914608088
# x88
# A2_min Temp_mean -1.8684567462556327 0.45239550704004017 -0.7251798476920435 -0.7127578604048763
# x89
# A2_min Temp_mean 1.617293676970091 2.521490955087512 -0.7127219155481537 0.09604580085554855
# x90
# Cur_min A2_mean -0.27514896423069996 -0.06379461071893328 0.05663066069930882 0.5223661250976115
# x91
# Cur_min A2_mean -0.06649517371749862 -0.06379461071893328 0.5376588404529723 2.74520869619521
# x92
# Cur_min A2_mean 4.865170906769863 5.100272855001104 -1.0741329680893572 1.014273008089858
# x93
# Cur_min Pre_max -0.19392911868377344 -0.19392911868377344 0.1800719792077492 1.7562115237607516
# x94
# Cur_min Pre_max 4.865170906769863 5.100272855001104 -0.22148947550810735 1.8867633219128181
# x95
# Cur_min Vol_max -0.25876815632570976 -0.06384328875960077 1.312542614665451 1.415061018676004
# x96
# Cur_min Vol_max 4.865170906769863 5.135404232215449 -3.3857414613227244 -1.6580017584929745
# x97
# Cur_min A2_min -0.27514896423069996 -0.06379461071893328 -0.3143539929846853 0.37936703091224744
# x98
# Cur_min A2_min 4.865170906769863 5.100272855001104 -1.5924735787651845 0.7296429592106958
# x99
# Temp_max A2_max -1.0721332007655113 -1.0613027356625888 -0.38657151316181115 1.4312342772918163
# x100
# Temp_max A2_max -0.7209660553367258 -0.7087437141728019 -1.155229295415656 1.0011400337935832
# x101
# Temp_max A2_max -0.7081994268494708 0.13863680301796039 2.3545783857920695 3.2244827465363226
# x102
# Cur_mean Flow_min -0.23814384328189536 -0.05607586508244061 -0.10431897283106706 -0.028119943440562862
# x103
# Cur_mean Flow_min -0.055830521868447634 7.701455451063613 -0.10253383753753509 -0.028322486835736436
# x104
# Cur_mean Flow_min 5.210511608004405 9.33936415719963 0.057444553437952704 0.6401557902808621
# x105
# A2_mean Temp_mean -0.9554800377614765 0.7065756893789962 -1.0783061435159829 -1.0680852914608088
# x106
# A2_mean Temp_mean -1.6094042652607943 0.8311544535698052 -0.7251798476920435 -0.7127578604048763
# x107
# A2_mean Temp_mean 1.7309622960018465 2.8855761729250196 -0.7127219155481537 0.11004586508699307
# x108
# A2_min Temp_max -1.263746102719016 0.16858877885863277 -1.0721332007655113 -1.0613027356625888
# x109
# A2_min Temp_max -1.8684567462556327 0.45239550704004017 -0.7209660553367258 -0.7087437141728019
# x110
# A2_min Temp_max 1.617293676970091 2.697692678477782 -0.7083692408779251 0.11087278184192023
# x111
# Cur_min Vol_mean -0.22191976993837895 -0.0822270272341164 -5.598718099545486 -3.4893013860472815
# x112
# Cur_min Vol_mean -0.07618514507217282 -0.06649517371749862 -4.931948875599052 -3.424289239347504
# x113
# Cur_min Vol_mean 4.8801388972675275 5.135404232215449 -5.655913781108772 -3.9936654862744527
# x114
# A1_min Ther_mean -2.2252930322362867 -1.230100186215051 1.7096400923955133 2.159532594097616
# x115
# Cur_mean A2_mean 6.366134481581604 9.202193087996143 -1.3875536641406274 1.2494328822498777
# x116
# A1_mean Ther_mean -2.181749955412472 -1.132882248558283 1.7096400923955133 2.175217541149157
# x117
# A2_min Pre_max -1.9985355194764514 -1.7649796728676923 -0.8386626182020912 1.884901201050831
# x118
# A2_min Pre_max 1.617293676970091 6.644150777909581 0.8252490725541234 2.4221477373070965
# x119
# Pre_min Ther_mean -1.2623112625203345 1.1468245134370236 1.7096400923955133 2.1847636807692106
# x120
# Cur_mean Pre_mean -0.26556402872781965 -0.2363503484161255 -2.3846807388122544 1.846516559275591
# x121
# Cur_mean Pre_mean 6.331435050989396 9.33936415719963 -0.5153289845134077 0.21299745487867194
# x122
# Cur_mean Pre_mean 6.350594034610359 8.980931003495593 0.23202047591022373 1.3277569000132012
# x123
# Cur_max Pre_mean -0.15645394288609368 -0.12712242760447948 -2.512949698924481 2.19215770992638
# x124
# Cur_max Pre_mean 11.347009569407701 11.473207245846712 -0.5840327092765246 0.15430468314342857
# x125
# Cur_max Pre_mean 11.525525679908457 11.809957512933991 -0.7959495231497262 0.14404713399517582
# x126
# Cur_max Pre_mean 11.31198239380685 11.31198239380685 0.5140553374036422 0.9152688661020484
# x127
# Cur_max Pre_mean 11.313600075993469 11.809957512933991 0.16092791823302616 1.354209294974511
# x128
# Cur_mean Flow_max 5.210511608004405 9.33936415719963 0.2851227857489928 0.3940349761435906
# x129
# Cur_mean Flow_max 5.224064489425409 8.948879987192043 0.4848092118305071 0.7305130482842163
# x130
# A2_min Pre_mean -1.9985355194764514 -1.7649796728676923 -1.235345802238542 0.8495249479330604
# x131
# A2_min Pre_mean -0.5835151253065152 -0.5685807893666582 -1.839632918518997 2.1438100851999495
# x132
# A2_min Pre_mean 1.617293676970091 6.644150777909581 -0.10647685349458817 2.049489218752497
# x133
# Cur_min Ther_min -0.10744204678253623 -0.10609859911562286 -1.191820604732019 -1.191820604732019
# x134
# Cur_min Ther_min -0.2573292646088831 4.904837372804208 1.704450907581278 2.183591926982413
# x135
# Ther_min Vol_mean -1.191820604732019 -1.191820604732019 -1.305043271806848 -0.328772382753091
# x136
# Ther_min Vol_mean 1.704450907581278 2.183591926982413 -5.91814816627513 2.262533755161042
# x137
# Ther_min Ther_mean -1.191820604732019 -1.191820604732019 -1.1897521247724303 -1.1873234059069897
# x138
# Ther_min Ther_mean 1.704450907581278 2.183591926982413 1.7084544400488553 2.1847636807692106
# x139
# Ther_min Pre_mean -1.191820604732019 -1.191820604732019 -1.0699484155301249 -0.2655718675236466
# x140
# Ther_min Pre_mean 1.704450907581278 2.183591926982413 -2.059390923023236 2.19215770992638
# x141
# Ther_min A1_mean -1.191820604732019 -1.191820604732019 0.5938930477075757 1.0218346655654404
# x142
# Ther_min A1_mean 1.704450907581278 2.183591926982413 -2.866209832509367 -1.132882248558283
# x143
# Ther_min Pre_min -1.191820604732019 -1.191820604732019 -2.318166557856439 -0.6258746936493909
# x144
# Ther_min Pre_min 1.704450907581278 2.183591926982413 -2.7296356467602854 1.1468245134370236
# x145
# Ther_min Vol_min -1.191820604732019 -1.191820604732019 -1.830743963321451 -1.7759417645212932
# x146
# Ther_min Vol_min 1.704450907581278 2.183591926982413 -7.443484860686866 1.833670215944678
# x147
# Ther_min A2_mean -1.191820604732019 -1.191820604732019 -0.3412539325567061 0.5780053427832402
# x148
# Ther_min A2_mean 1.704450907581278 2.183591926982413 -1.6676068195167617 0.9709124145907394
# x149
# Ther_min Pre_max -1.191820604732019 -1.191820604732019 0.03335132643163235 0.055909040668817106
# x150
# Ther_min Pre_max 1.704450907581278 2.183591926982413 -1.2934167781307058 2.9864700886731765
# x151
# Ther_min A1_min -1.191820604732019 -1.191820604732019 0.38771463464712014 0.6894465962944237
# x152
# Ther_min A1_min 1.704450907581278 2.183591926982413 -3.0729378920587016 -1.230100186215051
# x153
# Ther_min Vol_max -1.191820604732019 -1.191820604732019 -0.4901971114382677 0.679185178652541
# x154
# Ther_min Vol_max 1.704450907581278 2.183591926982413 -3.837670718703486 2.649686382698148
# x155
# A2_min Ther_min -0.5685807893666582 0.055072117137405056 -1.191820604732019 -1.191820604732019
# x156
# A2_min Ther_min -1.8304536862723366 0.7851407512187634 1.704450907581278 2.183591926982413
# x157
# Cur_mean Ther_min -0.10156258926615788 -0.08130003785533066 -1.191820604732019 -1.191820604732019
# x158
# Cur_mean Ther_min -0.23302030595607048 8.962181002895557 1.704450907581278 2.183591926982413
# x159
# Ther_max Ther_min -1.1885351164364664 -1.180419147448209 -1.191820604732019 -1.191820604732019
# x160
# Ther_max Ther_min 1.7129415534993302 2.1861151436681077 1.704450907581278 2.183591926982413
# x161
# Pre_max A2_mean -0.8386626182020912 1.5562981657718766 -1.8376573705874932 -1.6049961689405954
# x162
# Pre_max A2_mean -1.7768422558782877 2.1542383288261475 -0.18047208237296347 0.5223661250976115
# x163
# Pre_max A2_mean 0.582619589441167 2.4221477373070965 1.7309622960018465 6.752963044284689
# x164
# A2_mean Pre_mean -1.8376573705874932 -1.6049961689405954 -1.127783230786811 0.9601053961335962
# x165
# A2_mean Pre_mean 1.7326891349951883 6.752963044284689 -0.2573285706304055 2.049489218752497
# x166
# Pre_max Cur_max -1.9888367480156697 3.2487551090983176 -0.15645394288609368 -0.12712242760447948
# x167
# Pre_max Cur_max -0.03904539756284746 0.6330551890820011 11.347009569407701 11.473207245846712
# x168
# Pre_max Cur_max -0.2753177844750557 0.620113964664673 11.525525679908457 11.809957512933991
# x169
# Pre_max Cur_max 1.1597657378543516 1.219884485168545 11.31198239380685 11.31198239380685
# x170
# Pre_max Cur_max 0.6772003503755901 1.8867633219128181 11.313600075993469 11.809957512933991
# x171
# A2_min Ther_mean -1.843011576533383 -1.7588410279941322 1.7096400923955133 2.112981678674841
# x172
# A2_min Ther_mean -1.7439730579561437 0.7851407512187634 1.710356771199249 2.1847636807692106
# x173
# Ther_max Ther_mean 1.7188604449999048 1.8116556010551677 1.7096400923955133 1.7955528775494745
# x174
# Ther_max Ther_mean 1.8017454962615642 2.1861151436681077 1.7956376951438773 2.1847636807692106
# x175
# Cur_mean Ther_mean -0.18288867239280043 8.962181002895557 1.7096400923955133 1.7955528775494745
# x176
# Cur_mean Ther_mean -0.23302030595607048 0.024182567879849563 1.7956376951438773 2.1847636807692106
# x177
# Cur_min Ther_mean -0.1988819364822133 4.904837372804208 1.7096400923955133 1.7955528775494745
# x178
# Cur_min Ther_mean -0.2573292646088831 0.013138606415613839 1.7956376951438773 2.1847636807692106
# x179
# Pre_max Ther_mean -0.4344424791801999 1.622207608887332 1.7096400923955133 1.7955528775494745
# x180
# Pre_max Ther_mean -1.2934167781307058 2.9864700886731765 1.7956376951438773 2.1847636807692106
# x181
# Pre_mean Ther_mean -0.8918402225961041 0.7732737068280843 1.7096400923955133 1.7955528775494745
# x182
# Pre_mean Ther_mean -2.059390923023236 2.19215770992638 1.7956376951438773 2.1847636807692106
# x183
# Cur_mean Flow_mean 5.210511608004405 9.33936415719963 0.1164958594530299 0.4373581471961206
# x184
# Cur_mean Flow_mean 5.224064489425409 8.948879987192043 0.4459798097694049 0.6896058661086901
# x185
# A1_max Flow_min 1.4841988366768468 2.0671507145886063 -0.8825514589020836 -0.1177771717745709
# x186
# A1_max Flow_min -1.7336478422297457 -0.2301578292071086 -0.10431897283106706 -0.02935094877337347
# x187
# A1_max Flow_min -0.2222030404741678 1.4994004567377162 -0.10214427005877955 -0.028119943440562862
# x188
# A1_max Flow_min 0.816190673110925 2.4468482691036386 -0.027345067207716508 0.9680929570274126
# x189

# %%
from imblearn.combine import SMOTEENN

# Data augmentation using SMOTEENN
smoteenn = SMOTEENN(random_state=0)
train_x_aug, train_y_aug = smoteenn.fit_resample(new_train_x, train_y)

# %%
lgb_params
# Out:
# {'objective': 'binary',
#  'metric': 'binary_error',
#  'force_row_wise': True,
#  'seed': 0,
#  'learning_rate': 0.0424127,
#  'min_data_in_leaf': 15,
#  'max_depth': 24,
#  'num_leaves': 29}

# %%
test_acc,test_f1score,test_cm,test_pred,model_lgb_aug=lgb_train_predict(train_x_aug,train_y_aug,new_val_x,valid_y,new_test_x,test_y,params=lgb_params,test_flag=True)

print('test_acc:' + str(test_acc))
print('test_f1score:' + str(test_f1score))
print('test_confusionMatrix')
display(test_cm)

plt.figure(figsize=(10,5))
plt.plot(range(len(test_y)),test_y,linestyle='none', marker='X', color='blue', markersize=5, label='Anomaly')
plt.plot(range(len(test_pred)),test_pred,linestyle='none', marker='X', color='red', markersize=5, label='Predict',alpha=0.05)
plt.title('Light GBM')
plt.xlabel('index')
plt.ylabel('label')
plt.legend(loc='best')
# Out:
# [LightGBM] [Info] Number of positive: 8351, number of negative: 8263
# [LightGBM] [Info] Total Bins 6466
# [LightGBM] [Info] Number of data points in the train set: 16614, number of used features: 197
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502648 -> initscore=0.010594
# [LightGBM] [Info] Start training from score 0.010594
# test_acc:0.9219088937093276
# test_f1score:0.9029649595687331
# test_confusionMatrix
# array([[1030,   11],
#        [ 133,  670]])

# %% [markdown]
# As the result of calculation, Flow min (The minimum of Volume Flow RateRMS) highly contributes to the decision of the class.
#
# Valve1_data includes the anomaly data occurring when the valve is closed.
#
# It leads to decrease Flow min when the valve is closed ,so this stat reflects the decision of the class mostly.
#
# This result is coincident with the correlation coeficient result:
#
# having the strong negative correlation -0.62 between "Volume Flow RateRMS" and "anomaly".

# %% [markdown]
# # 6. Conclusion
#
# We use the TS data with supervised class label(normal, anomaly) and then construct the LightGBM model.
#
# Before we implement data standardization, we perform Kaiser window data smoothing to remove the residual error.
#
# In constructing the anomaly model, we introduce the window which is parameterized by look_back and
# calculate the stats like mean, min and max within the window area.
#
# We assign these stats as the explanatory variable.
#
# Also, we assign the class label at right end of window as the objective variable.
#
# After this, we train the model using the training data and search the hyper parameter.
#
# Finally, we assess the generalization performance like the accuracy, f1score and confusion matrix.
#
# We obtained the f1 score : 89 percent, so we can say that our model is good-balance in terms of recall and precision.
